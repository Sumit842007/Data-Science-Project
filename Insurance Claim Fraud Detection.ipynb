# %%
import pandas as pd
import numpy as np

# %%
# loading the dataset
pd.set_option('display.max_columns', None)
df=pd.read_csv(r'D:\Datatrained\Practice Project Data Trained\Insurance Claim Fraud Detection\Automobile_insurance_fraud.csv')
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
# checking datatype of column

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
# No null value in dataset,_c39 feature has null values

# %%
df=df.drop(['_c39'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [raw]
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %% [raw]
# Making Dataframe for Nominal Data

# %%
Categorical_columns=[x for x in df.dtypes.index if df.dtypes[x]=='object']

# %%
Categorical_columns
# Out:
# ['policy_state',
#  'policy_csl',
#  'insured_sex',
#  'insured_education_level',
#  'insured_occupation',
#  'insured_hobbies',
#  'insured_relationship',
#  'incident_type',
#  'collision_type',
#  'incident_severity',
#  'authorities_contacted',
#  'incident_state',
#  'incident_city',
#  'incident_location',
#  'property_damage',
#  'police_report_available',
#  'auto_make',
#  'auto_model',
#  'fraud_reported']

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
#Analysing Categorical Variable

# %% [raw]
# It should be converted in do Date Format

# %%
df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])

# %%
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df['policy_bind_date'].value_counts()
# Out:
# 1992-05-08    3
# 2006-01-01    3
# 1992-04-28    3
# 2014-05-07    2
# 1997-03-02    2
#              ..
# 2003-03-16    1
# 2006-07-19    1
# 1992-10-04    1
# 1995-02-17    1
# 1996-08-07    1
# Name: policy_bind_date, Length: 951, dtype: int64

# %%
df_visualization_nominal=df[['policy_state','policy_csl','insured_sex','insured_education_level','insured_occupation',
 'insured_hobbies','insured_relationship','incident_type','collision_type','incident_severity','authorities_contacted',
 'incident_state','incident_city','incident_location','property_damage','police_report_available','auto_make','auto_model',
 'fraud_reported']].copy()

# %%
import seaborn as sns

# %%
ax=sns.countplot(x="policy_state",data=df_visualization_nominal)
print(df_visualization_nominal['policy_state'].value_counts())
# Out:
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %% [raw]
# There are three states from where insured belong to

# %%
ax=sns.countplot(x="policy_csl",data=df_visualization_nominal)
print(df_visualization_nominal['policy_csl'].value_counts())
# Out:
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64

# %% [raw]
# CSL is a single number that describes the predetermined limit for the combined total of the Bodily Injury Liability coverage and Property Damage Liability coverage per occurrence or accident.

# %%
ax=sns.countplot(x="insured_sex",data=df_visualization_nominal)
print(df_visualization_nominal['insured_sex'].value_counts())
# Out:
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %%
# Male is less in number as compare to Female

# %%
ax=sns.countplot(x="insured_education_level",data=df_visualization_nominal)
print(df_visualization_nominal['insured_education_level'].value_counts())
# Out:
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64

# %%
# Majority insured are having  college level and above degree

# %%
ax=sns.countplot(x="insured_occupation",data=df_visualization_nominal)
print(df_visualization_nominal['insured_occupation'].value_counts())
# Out:
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# exec-managerial      76
# sales                76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %%
# Mix insured_occupation

# %%
ax=sns.countplot(x="insured_hobbies",data=df_visualization_nominal)
print(df_visualization_nominal['insured_hobbies'].value_counts())
# Out:
# reading           64
# paintball         57
# exercise          57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# base-jumping      49
# skydiving         49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64

# %%
# Mix insured_hobbies

# %%
ax=sns.countplot(x="insured_relationship",data=df_visualization_nominal)
print(df_visualization_nominal['insured_relationship'].value_counts())
# Out:
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64

# %%
#own-child-183 is max in number

# %%
ax=sns.countplot(x="collision_type",data=df_visualization_nominal)
print(df_visualization_nominal['collision_type'].value_counts())
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %%
#collision_type for 178 insured is unkown

# %%
ax=sns.countplot(x="authorities_contacted",data=df_visualization_nominal)
print(df_visualization_nominal['authorities_contacted'].value_counts())
# Out:
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64

# %%
#authorities_contacted is none for 91

# %%
ax=sns.countplot(x="incident_city",data=df_visualization_nominal)
print(df_visualization_nominal['incident_city'].value_counts())
# Out:
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64

# %%
ax=sns.countplot(x="incident_location",data=df_visualization_nominal)
print(df_visualization_nominal['incident_location'].value_counts())
# Out:
# 5383 Maple Drive      1
# 5506 Best St          1
# 6435 Texas Ave        1
# 1358 Maple St         1
# 7740 MLK St           1
#                      ..
# 3847 Elm Hwy          1
# 4538 Flute Hwy        1
# 5352 Lincoln Drive    1
# 3769 Sky St           1
# 3100 Best St          1
# Name: incident_location, Length: 1000, dtype: int64

# %%
ax=sns.countplot(x="police_report_available",data=df_visualization_nominal)
print(df_visualization_nominal['police_report_available'].value_counts())
# Out:
# ?      343
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %% [raw]
# for 343 insured,police_report_available is not known

# %%
ax=sns.countplot(x="auto_make",data=df_visualization_nominal)
print(df_visualization_nominal['auto_make'].value_counts())
# Out:
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# BMW           72
# Ford          72
# Toyota        70
# Audi          69
# Volkswagen    68
# Accura        68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64

# %%
ax=sns.countplot(x="auto_model",data=df_visualization_nominal)
print(df_visualization_nominal['auto_model'].value_counts())
# Out:
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# Legacy            32
# A5                32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# 95                27
# F150              27
# E400              27
# Grand Cherokee    25
# 93                25
# Escape            24
# Maxima            24
# Tahoe             24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# CRV               20
# Impreza           20
# TL                20
# Corolla           20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64

# %%
ax=sns.countplot(x="fraud_reported",data=df_visualization_nominal)
print(df_visualization_nominal['fraud_reported'].value_counts())
# Out:
# N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %% [raw]
# Fraud reported is less in number as compared to actual

# %%
ax=sns.countplot(x="incident_type",data=df_visualization_nominal)
print(df_visualization_nominal['incident_type'].value_counts())
# Out:
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %%
# Majority claims from Multi-vehicle Collision and Single Vehicle Collision

# %%
#Analysis of continueous variable

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
df_visualization_Continueous=df[['months_as_customer','age','policy_number','policy_bind_date','policy_deductable',
 'policy_annual_premium','umbrella_limit','insured_zip','capital-gains','capital-loss','incident_date',
 'incident_hour_of_the_day','number_of_vehicles_involved','total_claim_amount','injury_claim','property_claim','vehicle_claim']].copy()

# %%
df_visualization_Continueous
# Out:
#      months_as_customer  age  policy_number policy_bind_date  \
# 0                   328   48         521585       2014-10-17
# 1                   228   42         342868       2006-06-27
# 2                   134   29         687698       2000-06-09
# 3                   256   41         227811       1990-05-25
# 4                   228   44         367455       2014-06-06
# ..                  ...  ...            ...              ...
# 995                   3   38         941851       1991-07-16
# 996                 285   41         186934       2014-05-01
# 997                 130   34         918516       2003-02-17
# 998                 458   62         533940       2011-11-18
# 999                 456   60         556080       1996-11-11
#
#      policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                 1000                1406.91               0       466132
# 1                 2000                1197.22         5000000       468176
# ...

# %%
df_visualization_Continueous.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   datetime64[ns]
#  4   policy_deductable            1000 non-null   int64
#  5   policy_annual_premium        1000 non-null   float64
#  6   umbrella_limit               1000 non-null   int64
#  7   insured_zip                  1000 non-null   int64
#  8   capital-gains                1000 non-null   int64
#  9   capital-loss                 1000 non-null   int64
#  10  incident_date                1000 non-null   datetime64[ns]
#  11  incident_hour_of_the_day     1000 non-null   int64
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df_visualization_Continueous:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df_visualization_Continueous[column])
        plt.xlabel(column,fontsize=20)
       
    
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sumit\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [raw]
# left Skewed
#
# months_as_customer,age,policy_annual_premium,capital-gains,total_claim_amount,injury_claim,property_claim
#
# Right Skewed
#
# months_as_customer,age,policy_annual_premium,capital-gains,total_claim_amount,injury_claim,property_claim

# %%
# number_of_vehicles_involved,policy_number,insured_zip

# %% [raw]
# "policy_deductable" is numerical not categorical
# please check the dtype if it is object then we can say it is categorical\it is numerical no need to convert
# just use the scaling techniques to scale the data like standard scaler

# %%
df['policy_deductable'].value_counts()
# Out:
# 1000    351
# 500     342
# 2000    307
# Name: policy_deductable, dtype: int64

# %% [raw]
# if the dataset have negaitve values then use min max scaler
# no need to delete those column which have negative values

# %%
df['capital-loss'].value_counts()
# Out:
#  0        475
# -53700      5
# -50300      5
# -31700      5
# -49200      4
#          ...
# -32600      1
# -46800      1
# -50600      1
# -40800      1
# -43900      1
# Name: capital-loss, Length: 354, dtype: int64

# %%
# 
df['umbrella_limit'].value_counts()
# Out:
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: umbrella_limit, dtype: int64

# %%
df['policy_number'].value_counts()
# Out:
# 116735    1
# 107181    1
# 430794    1
# 115399    1
# 328387    1
#          ..
# 218456    1
# 179538    1
# 357713    1
# 247116    1
# 296960    1
# Name: policy_number, Length: 1000, dtype: int64

# %%
df['insured_zip'].value_counts()
# Out:
# 446895    2
# 456602    2
# 477695    2
# 469429    2
# 431202    2
#          ..
# 468313    1
# 474360    1
# 476502    1
# 460895    1
# 454656    1
# Name: insured_zip, Length: 995, dtype: int64

# %%
df['number_of_vehicles_involved'].value_counts()
# Out:
# 1    581
# 3    358
# 4     31
# 2     30
# Name: number_of_vehicles_involved, dtype: int64

# %%
df['umbrella_limit'].value_counts()
# Out:
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: umbrella_limit, dtype: int64

# %%
df['incident_hour_of_the_day'].value_counts()
# Out:
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 4     46
# 13    46
# 10    46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 7     40
# 19    40
# 12    40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: incident_hour_of_the_day, dtype: int64

# %%
df['months_as_customer'].value_counts()
# Out:
# 194    8
# 285    7
# 140    7
# 230    7
# 128    7
#       ..
# 347    1
# 113    1
# 337    1
# 117    1
# 0      1
# Name: months_as_customer, Length: 391, dtype: int64

# %%
#Plotting Boxplot to understand outlier

df.boxplot(figsize=[20,8],)
plt.subplots_adjust(bottom=.001)
plt.show()
