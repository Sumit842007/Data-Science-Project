# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# loading the dataset
df=pd.read_csv(r'D:\Datatrained\Practice Project Data Trained\Temprature Prediction\temperature.csv')
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947
# 1         29.850689         24.035009  5.691890   51.937448   0.225508
# 2         30.091292         24.565633  6.138224   20.573050   0.209344
# 3         29.704629         23.326177  5.650050   65.727144   0.216372
# 4         29.113934         23.486480  5.735004  107.965535   0.151407
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# ...

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.dtypes.value_counts() # Compte les nombre de types de variables
# Out:
# float64    24
# dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(),cbar=False)
plt.show()
print((df.isna().sum()/df.shape[0]*100).sort_values(ascending=False))
# Out:
# Next_Tmin           0.0
# Next_Tmax           0.0
# Present_Tmax        0.0
# Present_Tmin        0.0
# LDAPS_RHmin         0.0
# LDAPS_RHmax         0.0
# LDAPS_Tmax_lapse    0.0
# LDAPS_Tmin_lapse    0.0
# LDAPS_WS            0.0
# LDAPS_LH            0.0
# LDAPS_CC1           0.0
# LDAPS_CC2           0.0
# LDAPS_CC3           0.0
# LDAPS_CC4           0.0
# LDAPS_PPT1          0.0
# LDAPS_PPT2          0.0
# LDAPS_PPT3          0.0
# LDAPS_PPT4          0.0
# lat                 0.0
# lon                 0.0
# DEM                 0.0
# Slope               0.0
# Solar radiation     0.0
# station             0.0
# dtype: float64

# %%
plt.figure(figsize=(18, 6), dpi=80)
plt.plot(df["Next_Tmax"],label="Next_Tmax")
plt.plot(df["Next_Tmin"],label="Next_Tmin")
plt.legend()
plt.show()

# %%
for col in ["Next_Tmax","Next_Tmin"]:
    plt.figure()
    sns.displot(df[col],kind='kde')
    plt.show()
print(df["Next_Tmax"].mean())
print(df["Next_Tmax"].std())
print(df["Next_Tmin"].mean())
print(df["Next_Tmin"].std())
# Out:
# 30.24097496706193
# 3.1164722206401816
# 22.910197628458533
# 2.48676217703319

# %%
plt.figure()
sns.heatmap(pd.crosstab(df['Next_Tmax'],df['Next_Tmin']))
plt.show()

# %%
df['Date'].value_counts()
# Out:
# 02-08-2017    25
# 22-08-2015    25
# 03-08-2015    25
# 12-07-2016    25
# 13-08-2016    25
# 26-08-2013    25
# 07-07-2014    25
# 12-07-2015    25
# 21-07-2014    25
# 19-07-2015    25
# 11-07-2014    25
# 04-08-2014    25
# 07-07-2015    25
# 19-08-2013    25
# 31-07-2015    25
# 27-08-2017    25
# 22-07-2015    25
# 10-08-2016    25
# 27-08-2015    25
# 09-08-2017    25
# 11-07-2015    25
# 03-08-2017    25
# 01-07-2014    25
# 02-07-2015    25
# 18-07-2015    25
# 08-07-2016    25
# 20-08-2013    25
# 17-07-2016    25
# 30-06-2017    25
# 06-08-2016    25
# 01-08-2013    25
# 03-07-2013    25
# 19-07-2017    25
# 02-08-2015    25
# 06-07-2016    25
# 10-08-2013    25
# 29-08-2017    25
# 17-08-2017    25
# 05-07-2013    25
# 04-07-2017    25
# 12-07-2017    25
# 08-07-2013    25
# 18-08-2017    25
# 19-07-2013    25
# 20-07-2015    25
# 09-08-2016    25
# 28-08-2017    25
# 14-07-2015    25
# 22-08-2013    25
# 07-08-2015    25
# 27-08-2014    25
# 14-07-2017    25
# ...

# %%
df=df.drop(['Date'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Present_Tmax      7682 non-null   float64
#  2   Present_Tmin      7682 non-null   float64
#  3   LDAPS_RHmin       7677 non-null   float64
#  4   LDAPS_RHmax       7677 non-null   float64
#  5   LDAPS_Tmax_lapse  7677 non-null   float64
#  6   LDAPS_Tmin_lapse  7677 non-null   float64
#  7   LDAPS_WS          7677 non-null   float64
#  8   LDAPS_LH          7677 non-null   float64
#  9   LDAPS_CC1         7677 non-null   float64
#  10  LDAPS_CC2         7677 non-null   float64
#  11  LDAPS_CC3         7677 non-null   float64
#  12  LDAPS_CC4         7677 non-null   float64
#  13  LDAPS_PPT1        7677 non-null   float64
#  14  LDAPS_PPT2        7677 non-null   float64
#  15  LDAPS_PPT3        7677 non-null   float64
# ...

# %%
# treating outlier values
df['station']=df['station'].fillna(df['station'].mode()[0])
#df['Date']=df['Date'].fillna(df['Date'].mode()[0])
df['Present_Tmax']=df['Present_Tmax'].fillna(df['Present_Tmax'].mean())
df['Present_Tmin']=df['Present_Tmin'].fillna(df['Present_Tmin'].mean())
df['LDAPS_RHmin']=df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())
df['LDAPS_RHmax']=df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].mean())
df['LDAPS_Tmax_lapse']=df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())
df['LDAPS_Tmin_lapse']=df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())
df['LDAPS_WS']=df['LDAPS_WS'].fillna(df['LDAPS_WS'].mean())
df['LDAPS_LH']=df['LDAPS_LH'].fillna(df['LDAPS_LH'].mean())
df['LDAPS_CC1']=df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].mean())
df['LDAPS_CC2']=df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].mean())
df['LDAPS_CC3']=df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].mean())
df['LDAPS_CC4']=df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].mean())
df['LDAPS_PPT1']=df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())
df['LDAPS_PPT2']=df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())
df['LDAPS_PPT3']=df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())
df['LDAPS_PPT4']=df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())
# Out:
# <ipython-input-163-a06ddbcf3fe2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['station']=df['station'].fillna(df['station'].mode()[0])
# <ipython-input-163-a06ddbcf3fe2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Present_Tmax']=df['Present_Tmax'].fillna(df['Present_Tmax'].mean())
# <ipython-input-163-a06ddbcf3fe2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df=df.dropna()

# %%
#Looking for null value in feature after null treatment
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
# checking data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7590 entries, 0 to 7751
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7590 non-null   float64
#  1   Present_Tmax      7590 non-null   float64
#  2   Present_Tmin      7590 non-null   float64
#  3   LDAPS_RHmin       7590 non-null   float64
#  4   LDAPS_RHmax       7590 non-null   float64
#  5   LDAPS_Tmax_lapse  7590 non-null   float64
#  6   LDAPS_Tmin_lapse  7590 non-null   float64
#  7   LDAPS_WS          7590 non-null   float64
#  8   LDAPS_LH          7590 non-null   float64
#  9   LDAPS_CC1         7590 non-null   float64
#  10  LDAPS_CC2         7590 non-null   float64
#  11  LDAPS_CC3         7590 non-null   float64
#  12  LDAPS_CC4         7590 non-null   float64
#  13  LDAPS_PPT1        7590 non-null   float64
#  14  LDAPS_PPT2        7590 non-null   float64
#  15  LDAPS_PPT3        7590 non-null   float64
# ...

# %%
#No value is in Object,ther are either in float or datetime format

# %%
# Analysing data statstically

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7590.000000   7590.000000   7590.000000  7590.000000  7590.000000
# mean     13.010935     29.748116     23.195125    56.725610    88.358480
# std       7.219541      2.970487      2.405675    14.638640     7.207666
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.600000    45.960060    84.203716
# 50%      13.000000     29.900000     23.400000    55.023199    89.784122
# 75%      19.000000     32.000000     24.800000    67.116507    93.743328
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7590.000000       7590.000000  7590.000000  7590.000000
# mean          29.619723         23.511374     7.095487    62.502465
# std            2.948107          2.345718     2.183869    33.737553
# ...

# %% [raw]
# std high for LDAPS_RHmin,LDAPS_WS,LDAPS_LH,LDAPS_CC1,LDAPS_CC,LDAPS_CC3,LDAPS_CC4,LDAPS_PPT1,LDAPS_PPT2,LDAPS_PPT3,LDAPS_PPT4,DEM,Slope
# Min value for LDAPS_LH is negative
# Min Value for LDAPS_LH,LDAPS_CC1,LDAPS_CC,LDAPS_CC3,LDAPS_CC4,LDAPS_PPT1,LDAPS_PPT2,LDAPS_PPT3,LDAPS_PPT4 is zero
#
# High gap in Min and Max
# LDAPS_LH
#
# Zero value in 1st,2nd and 3rd quartile for LDAPS_PPT1,LDAPS_PPT2,LDAPS_PPT3,LDAPS_PPT4
#
# It seems there is outlier in Dataset

# %% [raw]
# #Identify Categorical and Continueous variable
#
# station,lat,lon,slope

# %%
df['station'].value_counts()
# Out:
# 25.0    307
# 18.0    307
# 2.0     307
# 17.0    307
# 10.0    307
# 23.0    307
# 3.0     306
# 4.0     306
# 13.0    305
# 1.0     305
# 16.0    304
# 20.0    304
# 21.0    304
# 14.0    303
# 15.0    302
# 12.0    302
# 22.0    302
# 9.0     302
# 24.0    302
# 19.0    302
# 11.0    301
# 7.0     301
# 6.0     301
# 8.0     300
# 5.0     296
# Name: station, dtype: int64

# %%
df['lat'].value_counts()
# Out:
# 37.5776    1214
# 37.5507    1204
# 37.6181     611
# 37.6046     610
# 37.5237     609
# 37.5372     608
# 37.4967     605
# 37.4697     604
# 37.5102     603
# 37.4562     308
# 37.4832     307
# 37.6450     307
# Name: lat, dtype: int64

# %%
df['lon'].value_counts()
# Out:
# 127.099    307
# 126.955    307
# 127.024    307
# 126.970    307
# 126.891    307
# 127.032    307
# 127.022    306
# 127.058    306
# 127.083    305
# 126.995    304
# 127.040    304
# 127.004    304
# 126.826    303
# 126.927    303
# 126.991    303
# 126.938    302
# 126.937    302
# 126.909    302
# 127.086    302
# 126.988    302
# 127.042    301
# 126.838    301
# 127.085    301
# 126.910    300
# 127.135    297
# Name: lon, dtype: int64

# %%
df['Slope'].value_counts()
# Out:
# 0.697000    307
# 1.231300    307
# 0.155400    307
# 0.514100    307
# 0.271300    307
# 5.178200    307
# 2.534800    306
# 0.266100    306
# 2.686500    305
# 0.572100    304
# 2.257900    304
# 4.729600    304
# 0.618000    303
# 2.785000    303
# 0.133200    302
# 0.593100    302
# 0.222300    302
# 0.412500    302
# 1.767800    302
# 0.855200    302
# 0.145700    301
# 0.098500    301
# 0.623300    301
# 1.562900    300
# 0.505500    296
# 0.098475      1
# 5.178230      1
# Name: Slope, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=36:
        ax=plt.subplot(6,6,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
       
    
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\sumit\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\sumit\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [raw]
# Right Skewed feature
# LDAPS_WS,LDAPS_LH,LDAPS_CC1,LDAPS_CC2,LDAPS_CC3,LDAPS_CC4,LDAPS_PPT1,LDAPS_PPT2,LDAPS_PPT3,LDAPS_PPT4,Solar radiation
# Left Skewed feature
# 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin','LDAPS_RHmax',LDAPS_LH,LDAPS_CC1', 'LDAPS_CC2,LDAPS_CC3', 'LDAPS_CC4',Solar radiation

# %% [raw]
# Categorical Values
# 'station','Date','lat', 'lon','DEM', 'Slope'
# Continueous Variable
# 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
# 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
# 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
# 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'

# %%
y=df['Next_Tmax']
x=df.drop(columns=['Next_Tmax'])

# %%
# Visualizing relationship

#Relation between Output variable 'Next_Tmax' and features

plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=36:
        ax=plt.subplot(6,6,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Next_Tmax',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
# Significant relation found between Next_Tmax and other featurres

# %%
y1=df['Next_Tmin']
x1=df.drop(columns=['Next_Tmin'])

# %%
#Relation between Output variable 'Next_Tmax' and features

plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x1:
    if plotnumber<=36:
        ax=plt.subplot(6,6,plotnumber)
        plt.scatter(x1[column],y1)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Next_Tmin',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
# Significant relation found between Next_Tmin and other featurres

# %% [raw]
# # checking correlation

# %%
# Multivariate
corr_mat=df.corr() 
corr_mat
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113267      0.133423    -0.067829
# Present_Tmax      0.113267      1.000000      0.616291    -0.206529
# Present_Tmin      0.133423      0.616291      1.000000     0.124516
# LDAPS_RHmin      -0.067829     -0.206529      0.124516     1.000000
# LDAPS_RHmax      -0.168533     -0.303867     -0.015260     0.579035
# LDAPS_Tmax_lapse  0.069941      0.574947      0.469881    -0.565579
# LDAPS_Tmin_lapse  0.105376      0.629656      0.772811     0.087319
# LDAPS_WS          0.004741     -0.122206     -0.034831     0.291387
# LDAPS_LH         -0.132348      0.136401     -0.009656    -0.069574
# LDAPS_CC1         0.006341     -0.314411      0.085882     0.613281
# LDAPS_CC2         0.003305     -0.215191      0.091572     0.745043
# LDAPS_CC3        -0.000467     -0.144658     -0.002900     0.688440
# LDAPS_CC4         0.004673     -0.141384     -0.044822     0.514552
# ...

# %%
plt.figure(figsize= [22,21])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
# No strong correlation observed

# %%
#Plotting Boxplot to understand outlier

df.boxplot(figsize=[20,8],)
plt.subplots_adjust(bottom=.25)
plt.show()

# %% [raw]
# Outlier at higher side and lower side observed for most of feature

# %%
df.iloc[:,0:10].boxplot(figsize=[20,8],)
plt.subplots_adjust(bottom=.25)
plt.show()

# %% [raw]
# # Higher Side
# Present_Tmin,LDAPS_Tmax_lapse,LDAPS_WS,LDAPS_LH
#
# # Lower Side
# Present_Tmax,Present_Tmin,LDAPS_RHmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse

# %%
df.iloc[:,11:15].boxplot(figsize=[20,8],)
plt.subplots_adjust(bottom=.001)
plt.show()

# %%
# Higher Side
Present_Tmin,LDAPS_Tmax_lapse,LDAPS_WS,LDAPS_LH,LDAPS_PPT1,

# Lower Side
Present_Tmax,Present_Tmin,LDAPS_RHmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse

# %%
df.iloc[:,16:20].boxplot(figsize=[20,8],)
plt.subplots_adjust(bottom=.001)
plt.show()

# %% [raw]
# # Higher Side
# Present_Tmin,LDAPS_Tmax_lapse,LDAPS_WS,LDAPS_LH,LDAPS_PPT1,LDAPS_PPT3,LDAPS_PPT4
#
# # Lower Side
# Present_Tmax,Present_Tmin,LDAPS_RHmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse

# %%
df.iloc[:,21:25].boxplot(figsize=[20,8],)
plt.subplots_adjust(bottom=.001)
plt.show()

# %% [raw]
# # Higher Side
# Present_Tmin,LDAPS_Tmax_lapse,LDAPS_WS,LDAPS_LH,LDAPS_PPT1,LDAPS_PPT3,LDAPS_PPT4
#
# # Lower Side
# Present_Tmax,Present_Tmin,LDAPS_RHmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse

# %%
import numpy as np

# %%
q1=df.quantile(0.25)

#3rd quantile

q3=df.quantile(0.75)

# IQR

iqr=q3-q1

# %%
# Treating outlier on higher side

# %%
Present_Tmin,LDAPS_Tmax_lapse,LDAPS_WS,LDAPS_LH,LDAPS_PPT1,LDAPS_PPT3,LDAPS_PPT4

index=np.where(df['Present_Tmin']>(q3.Present_Tmin +(1.5*iqr.Present_Tmin)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_Tmax_lapse']>(q3.LDAPS_Tmax_lapse +(1.5*iqr.LDAPS_Tmax_lapse)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_WS']>(q3.LDAPS_WS +(1.5*iqr.LDAPS_WS)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_LH']>(q3.LDAPS_LH +(1.5*iqr.LDAPS_LH)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_PPT1']>(q3.LDAPS_PPT1 +(1.5*iqr.LDAPS_PPT1)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_PPT3LDAPS_PPT3']>(q3.LDAPS_PPT3 +(1.5*iqr.LDAPS_PPT3)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_PPT4']>(q3.LDAPS_PPT4 +(1.5*iqr.LDAPS_PPT4)))
df=df.drop(df.index[index])
df.reset_index()

# %%
# Treating outlier on lower side

Present_Tmax,Present_Tmin,LDAPS_RHmax,LDAPS_Tmax_lapse,LDAPS_Tmin_lapse

# %%
index=np.where(df['Present_Tmin']<(q1.Present_Tmin -(1.5*iqr.Present_Tmin)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['Present_Tmax']<(q1.Present_Tmax -(1.5*iqr.Present_Tmax)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_RHmax']<(q1.LDAPS_RHmax -(1.5*iqr.LDAPS_RHmax)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_Tmax_lapse']<(q1.LDAPS_Tmax_lapse -(1.5*iqr.LDAPS_Tmax_lapse)))
df=df.drop(df.index[index])
df.reset_index()

# %%
index=np.where(df['LDAPS_Tmin_lapse']<(q1.LDAPS_Tmin_lapse -(1.5*iqr.LDAPS_Tmin_lapse)))
df=df.drop(df.index[index])
df.reset_index()

# %%
df.shape
# Out:
# (4122, 25)

# %%
# Loss of data
(7725-4122)/7725

#There is loss of 46% data which is not desirable
# Out:
# 0.46640776699029124

# %%
# Lets try to clean data with Z score method

#Z Score technique

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7725 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7725 non-null   float64
#  1   Date              7725 non-null   datetime64[ns]
#  2   Present_Tmax      7725 non-null   float64
#  3   Present_Tmin      7725 non-null   float64
#  4   LDAPS_RHmin       7725 non-null   float64
#  5   LDAPS_RHmax       7725 non-null   float64
#  6   LDAPS_Tmax_lapse  7725 non-null   float64
#  7   LDAPS_Tmin_lapse  7725 non-null   float64
#  8   LDAPS_WS          7725 non-null   float64
#  9   LDAPS_LH          7725 non-null   float64
#  10  LDAPS_CC1         7725 non-null   float64
#  11  LDAPS_CC2         7725 non-null   float64
#  12  LDAPS_CC3         7725 non-null   float64
#  13  LDAPS_CC4         7725 non-null   float64
#  14  LDAPS_PPT1        7725 non-null   float64
#  15  LDAPS_PPT2        7725 non-null   float64
# ...

# %%
df.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947
# 1         29.850689         24.035009  5.691890   51.937448   0.225508
# 2         30.091292         24.565633  6.138224   20.573050   0.209344
# 3         29.704629         23.326177  5.650050   65.727144   0.216372
# 4         29.113934         23.486480  5.735004  107.965535   0.151407
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# 0   0.203896   0.161697   0.130928         0.0         0.0         0.0
# ...

# %% [raw]
# Applied z score method and Loss of data is 11% which is also not desirable.Proceeding without outlier detection

# %%
#Splitting fetures into input and output variable
y=df['Next_Tmax']
y1=df['Next_Tmin']
x=df.drop(columns=['Next_Tmax','Next_Tmin'])

# %%
X = df.drop(['Next_Tmax','Next_Tmin'],axis=1)
y_max = df["Next_Tmax"]
y_min = df["Next_Tmin"]

# %%
print(X.shape)
print(y_max.shape)
# Out:
# (7590, 22)
# (7590,)

# %%
from sklearn.model_selection import train_test_split
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
X_max_train,X_max_test,y_max_train,y_max_test =train_test_split(X,y_max,test_size=.30,random_state=42)

# %%
X_min_train,X_min_test,y_min_train,y_min_test =train_test_split(X,y_min,test_size=.30,random_state=42)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import cross_validate

# %% [raw]
# Part 1 - SGDRegressor

# %%
reg_max = make_pipeline(StandardScaler(),
                    SGDRegressor(loss='squared_loss', penalty='l2', max_iter=1000, tol=1e-3))
reg_max.fit(X_max_train, y_max_train)

reg_min = make_pipeline(StandardScaler(),
                    SGDRegressor(loss='squared_loss', penalty='l2', max_iter=1000, tol=1e-3))
reg_min.fit(X_min_train, y_min_train)

cv_results_min = cross_validate(reg_min, X_min_train, y_min_train, cv=5, scoring=('r2', "neg_root_mean_squared_error"), return_train_score=True)
cv_results_max = cross_validate(reg_max, X_max_train, y_max_train, cv=5, scoring=('r2', "neg_root_mean_squared_error"), return_train_score=True)

print('Next_Tmin :')
print('Test RMSE :' , -cv_results_min['test_neg_root_mean_squared_error'].mean())
print('Test r2 :' , cv_results_min['test_r2'].mean())
print("Train RMSE :" , -cv_results_min['train_neg_root_mean_squared_error'].mean())
print("Train r2 :" , cv_results_min['train_r2'].mean())
print("*------------------------------------------*")
print('Next_Tmax :')
print('Test RMSE :' , -cv_results_max['test_neg_root_mean_squared_error'].mean())
print('Test r2 :' , cv_results_max['test_r2'].mean())
print("Train RMSE :" , -cv_results_max['train_neg_root_mean_squared_error'].mean())
print("Train r2 :" , cv_results_max['train_r2'].mean())
# Out:
# Next_Tmin :
# Test RMSE : 1.0222213633412793
# Test r2 : 0.8316109554926406
# Train RMSE : 1.016425601670059
# Train r2 : 0.8339441745303487
# *------------------------------------------*
# Next_Tmax :
# Test RMSE : 1.4692966858097765
# Test r2 : 0.7797073372161771
# Train RMSE : 1.46382961642681
# Train r2 : 0.7817127600323971

# %%
Next_Tmin_predict = reg_min.predict(X_min_test)
Next_Tmax_predict = reg_max.predict(X_max_test)

# %%
plt.figure(figsize=(18,6))
plt.plot(y_min_test.to_numpy(),label="Next_Tmin")
plt.plot(Next_Tmin_predict,label="Next_Tmin_predict")
plt.legend()
plt.show()

plt.figure(figsize=(18,6))
plt.plot(y_max_test.to_numpy(),label="Next_Tmax")
plt.plot(Next_Tmax_predict,label="Next_Tmax_predict")
plt.legend()
plt.show()

# %% [raw]
# Part 2 - RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [70, 130],
    'max_features': [3, 6],
    'min_samples_leaf': [2, 3],
    'min_samples_split': [4, 8],
    'n_estimators': [1000, 500]
}
# Create a based model
rf = RandomForestRegressor()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

# %%
# Fit the grid search to the Max data

grid_search.fit(X_max_train, y_max_train)
print(grid_search.best_params_)
best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_max_test, y_max_test)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:  3.6min finished
# {'bootstrap': True, 'max_depth': 130, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 1000}
# Model Performance
# Average Error: 0.7012 degrees.
# Accuracy = 97.65%.

# %%
base_model = RandomForestRegressor(n_estimators = 10, random_state = 42)
base_model.fit(X_min_train, y_min_train)
base_accuracy = evaluate(base_model, X_min_test, y_min_test)

print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - base_accuracy) / base_accuracy))
# Out:
# Model Performance
# Average Error: 0.6239 degrees.
# Accuracy = 97.22%.
# Improvement of 0.45%.

# %%
Next_Tmax_TreeRegressor = RandomForestRegressor(random_state = 42, 
                                                bootstrap=True, max_depth=110, max_features=4, 
                                                min_samples_leaf=2, min_samples_split=4, n_estimators=900)
Next_Tmin_TreeRegressor = RandomForestRegressor(random_state = 42, 
                                                bootstrap=True, max_depth=70, max_features=6, 
                                                min_samples_leaf=2, min_samples_split=4, n_estimators=900)


print("---Next_Tmax---")
Next_Tmax_TreeRegressor.fit(X_max_train,y_max_train)
Next_Tmax_Accuracy = evaluate(Next_Tmax_TreeRegressor, X_max_test, y_max_test)

base_max_model = RandomForestRegressor(n_estimators = 10, random_state = 42)
base_max_model.fit(X_max_train, y_max_train)
base_max_accuracy = evaluate(base_max_model, X_max_test, y_max_test)

print('Improvement of {:0.2f}%.'.format( 100 * (Next_Tmax_Accuracy - base_max_accuracy) / base_max_accuracy))
print("---------")


print("---Next_Tmin---")
Next_Tmin_TreeRegressor.fit(X_min_train,y_min_train)
Next_Tmin_Accuracy = evaluate(Next_Tmin_TreeRegressor, X_min_test, y_min_test)

base_min_model = RandomForestRegressor(n_estimators = 10, random_state = 42)
base_min_model.fit(X_min_train, y_min_train)
base_min_accuracy = evaluate(base_min_model, X_min_test, y_min_test)

print('Improvement of {:0.2f}%.'.format( 100 * (Next_Tmin_Accuracy - base_min_accuracy) / base_min_accuracy))
print("---------")
# Out:
# ---Next_Tmax---
# Model Performance
# Average Error: 0.7149 degrees.
# Accuracy = 97.61%.
# Model Performance
# Average Error: 0.7813 degrees.
# Accuracy = 97.38%.
# Improvement of 0.23%.
# ---------
# ---Next_Tmin---
# Model Performance
# Average Error: 0.5541 degrees.
# Accuracy = 97.52%.
# Model Performance
# Average Error: 0.6239 degrees.
# Accuracy = 97.22%.
# Improvement of 0.32%.
# ---------

# %% [raw]
# By using RandomForest, we can reach accuracies on both targets up to 97% (+/-0.65°C), which is truely decent.

# %%
import pickle
filename='inhouse_diabetes.pkl'
pickle.dump(rf,open(filename,'wb'))
